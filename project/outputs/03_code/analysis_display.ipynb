# %% [markdown]
# # Analysis notebook — Financial Distress (Stage121)
# Display-only. Run `python run_all.py` first to generate `outputs/`.

# %%
import pandas as pd, json
from pathlib import Path
OUT = Path('..')  # this notebook lives in outputs/03_code; '..' = outputs/

# %% [markdown]
# ## Test metrics (primary threshold)

# %%
tm = pd.read_csv(OUT/'06_metrics/test_metrics.csv')
tm[tm.threshold_kind=='thr_opt_primary']

# %% [markdown]
# ## Cross-validation by fold

# %%
pd.read_csv(OUT/'06_metrics/cv_metrics_by_fold.csv')

# %% [markdown]
# ## Bootstrap 95% CIs

# %%
pd.read_csv(OUT/'06_metrics/test_metrics_bootstrap_ci.csv')

# %% [markdown]
# ## Robustness

# %%
pd.read_csv(OUT/'06_metrics/robustness_results.csv')

# %% [markdown]
# ## SHAP global importance (XGBoost) + figures

# %%
pd.read_csv(OUT/'07_explainability/shap_global_importance_xgb.csv').head(15)

# %%
from IPython.display import Image
Image(str(OUT/'08_figures/fig_precision_recall_curves.png'))
